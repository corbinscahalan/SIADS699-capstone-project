# %%
import api_utils as au
import extract_video_info as evi
import numpy as np
import pandas as pd
from typing import List, Set, Dict, Tuple, Optional
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

import sklearn
import cloudpickle

# %%
df = pd.read_json('data/rnn_data.json.gz', compression='gzip')

# Starting data ~293K rows

# %%
df.loc[ df['subtitles'].apply(lambda x: len(x) == 0), 'subtitles'] = " "

# %%
df2 = df[ df['subtitles'].apply(lambda x: len(' '.join(x)) > 500 )]

# %%
df2.loc[:,'subtitles'] = df2.loc[:,'subtitles'].apply(lambda x: ' '.join(x))
# Out:
# /var/folders/cq/w3_vjj113f1gwbzkhp327xh00000gn/T/ipykernel_20128/3993077998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:,'subtitles'] = df2.loc[:,'subtitles'].apply(lambda x: ' '.join(x))

# %%
vectorizer = TfidfVectorizer(stop_words = 'english', min_df = .3, max_df = .95, ngram_range=(1,2))

X = vectorizer.fit_transform(df2.subtitles)

# %%
pca = PCA(n_components = 5, random_state=11)

# %%
X_pca = pca.fit_transform(X.toarray())

# %%
pca.explained_variance_
# Out:
# array([0.06240621, 0.05025503, 0.03003561, 0.02643839, 0.02015723])

# %%
class Add_PCA(sklearn.base.TransformerMixin, sklearn.base.BaseEstimator):

    # Adds five rows for each video's subtitle transformation via TFIDF vectorizer and PCA

    def __init__(self):

        # Passing the pre-trained vectorizer and pca objects

        self.vectorizer = vectorizer
        self.pca = pca

        return None
    
    def fit(self, df: pd.DataFrame):

        return df

    def transform(self, df: pd.DataFrame):

        nd = df.copy()

        pca_cols = [ 'pca_' + str(n) for n in range(5) ]

        # Some subtitle fields may have empty lists; this is a poor fix

        nd.loc[ nd['subtitles'].apply(lambda x: len(x) == 0), 'subtitles'] = " "
        nd.loc[:,'subtitles'] = nd.loc[:,'subtitles'].apply(lambda x: ' '.join(x))

        X_vec = self.vectorizer.transform(nd.subtitles)
        X_pca = self.pca.transform(X_vec.toarray())

        df[pca_cols] = X_pca
        
        return df

# %%
class YT_features(sklearn.base.TransformerMixin, sklearn.base.BaseEstimator):

    """
    Features added by this transformer:
    
    vid_name_chars -- number of characters in the video title
    vid_name_words -- number of words in the video title
    desc_chars -- number of characters in the video description
    desc_words -- number of words in the video description
    subtitle_chars -- number of characters in the video subtitles
    subtitle_words -- number of words in the video subtitles
    subtitles_words_unique -- number of distinct words appearing in the video subtitles
    has_profanity -- whether the video subtitles contain (redacted) profanity (boolean)
    has_music -- whether the video indicates musical accompaniment (boolean)
    has_links -- whether the video description has URLs (boolean)
    link_perc -- how much of the description text is devoted to URLs
    
    
    """

    def __init__(self):

        return None

    def fit(self, df: pd.DataFrame):

        return df

    def transform(self, df: pd.DataFrame):

        nd = df.copy()

        bleep = '[ __ ]'
        music = '[Music]'
        url_regex = re.compile(r'http.*')

        # Handling degenerate cases

        nd.loc[ nd['subtitles'].apply(lambda x: len(x) == 0), 'subtitles'] = " "
        nd.loc[:,'subtitles'] = nd.loc[:,'subtitles'].apply(lambda x: x[0])

        nd.loc[ nd.description.isna(), 'description'] = " "

        # Adding features

        df.loc[:, 'vid_name_chars'] = nd.loc[:,'vid_name'].apply(len)
        df.loc[:, 'vid_name_words'] = nd.loc[:,'vid_name'].apply(lambda x: len(x.split()))

        df.loc[:, 'desc_chars'] = nd.loc[:,'description'].apply(len)
        df.loc[:, 'desc_words'] = nd.loc[:,'description'].apply(lambda x: len(x.split()))


        df.loc[:, 'subtitle_chars'] = nd.loc[:,'subtitles'].apply(len)
        df.loc[:, 'subtitle_words'] = nd.loc[:,'subtitles'].apply(lambda x: len(x.split()))
        df.loc[:, 'subtitle_words_unique'] = nd.loc[:,'subtitles'].apply(lambda x: len(set(x.split())))


        df.loc[:, 'has_profanity'] = nd.loc[:,'subtitles'].apply(lambda x: bleep in x)
        df.loc[:, 'has_music'] = nd.loc[:, 'subtitles'].apply(lambda x: music in x)

        df.loc[:, 'has_links'] = nd.loc[:, 'description'].apply(lambda x: bool(url_regex.search(x)))

        for i in nd.index:

            if df.loc[i, 'has_links']:
                desc = nd.loc[i, 'description']

                link_text = ''.join(url_regex.findall(desc))
                df.loc[i, 'link_perc'] = len(link_text) / len(desc)

            else:
                df.loc[i, 'link_perc'] = 0

        return df

# %%
ytt = YT_features()
pipe_pca = Add_PCA()

# %%
test_pipe = Pipeline(
    steps = [
        ('Basic Features', ytt),
        ('PCA', pipe_pca)

    ]
)

# %%
test_pipe.transform(df.sample(5))
# Out:
#               vid_id   chan_query                   chan_id  \
# 1070554  7ncXVNjNUlE         none  UCuw4-InDchDnYg0LPjHiGQA
# 34189    zwDDM0PXeFw         none  UCbRj3Tcy1Zoz3rcf83nW5kw
# 262231   KVERSJIK3kQ      gnocchi  UCIAJ7fd67S0XpsWk15jeIcQ
# 57992    LBcaPSbdtks         none  UC8Y-jrV8oR3s2Ix4viDkZtA
# 318121   Zzmd__QVZYU  smoked pork  UCfOZuEpYpw34VOjEUxL06dw
#
#                    chan_name  chan_viewcount  chan_subcount  \
# 1070554    Jessica O'Donohue        14321510         103000
# 34189    SAM THE COOKING GUY       524065067        3440000
# 262231         Cooking Light        10718341          43000
# 57992           Food Network       563975854        2150000
# 318121   Weekend Warrior BBQ         8123305          59500
#
#                 chan_start_dt  \
# 1070554  2011-09-30T00:38:07Z
# 34189    2011-07-22T05:32:54Z
# 262231   2006-08-12T15:20:38Z
# 57992    2006-11-16T09:06:09Z
# 318121   2017-06-17T13:49:32Z
#
#                                                 chan_thumb  chan_vidcount  \
# 1070554  https://yt3.ggpht.com/ytc/AMLnZu9fWg7hcb_UVKY3...            375
# 34189    https://yt3.ggpht.com/ytc/AMLnZu_J4iIfeusuVEFl...           1589
# 262231   https://yt3.ggpht.com/ytc/AMLnZu8EnMJDCK90eYOx...            890
# 57992    https://yt3.ggpht.com/AIUdnGJYCXdxZPNUtT5khTOb...           5067
# 318121   https://yt3.ggpht.com/ytc/AMLnZu8uhTFL2W7QOKls...            257
#
#                                                   vid_name  ...  \
# 1070554  HUGE WALMART GROCERY HAUL | EASY CROCKPOT RECI...  ...
# 34189       Simple Chicken Flatbread | SAM THE COOKING GUY  ...
# 262231   Cheesy Pull-Apart Eggplant | Wow! | Cooking Light  ...
# 57992    7 Tips for Baking a Cake From Our Food Network...  ...
# 318121   Smoked Pork Picnic | How to Smoke a Picnic Sho...  ...
#
#         subtitle_words_unique has_profanity has_music  has_links  link_perc  \
# 1070554                   540         False      True       True   0.158290
# 34189                     309         False     False       True   0.194139
# 262231                      1         False     False       True   0.304403
# 57992                       2         False     False       True   0.226510
# 318121                    570         False      True       True   0.253203
#
#             pca_0     pca_1     pca_2     pca_3     pca_4
# 1070554 -0.221926 -0.135469 -0.024123 -0.041443 -0.066559
# 34189   -0.170170 -0.155699  0.022694  0.089975  0.015101
# 262231   0.072432  0.743272  0.228359 -0.038117  0.094982
# 57992    0.146404  0.260532 -0.178524  0.025297  0.083467
# 318121  -0.118090 -0.197336  0.295464  0.311546  0.046933
#
# [5 rows x 51 columns]

# %%
cloudpickle.dump(test_pipe, open('data/feat_pca_pipe.cloudpickle', 'wb'))

# %%
recon = cloudpickle.load(open('data/feat_pca_pipe.cloudpickle', 'rb'))

# %%
recon.transform(df.sample(10))
# Out:
#               vid_id chan_query                   chan_id  \
# 235123   jgz5sYmS6o4   dulce de  UC51O5CJFmd_5cyvDfeHv1ZQ
# 1034336  3eoSbLpLA-w       none  UCqJkAAmi4QKCPCF62r_-BhQ
# 1089564  v8E4CkeEy1s       none  UCwiTOchWeKjrJZw7S1H__1g
# 114769   0PWBu2o2oyk       none  UCYk8BsOEXzccXnoLyhuhevQ
# 1107487  x1bebdk-SZ0       none  UCyeXIDrwTEyFe-16MWN9xZg
# 116572   gH7iXkJlUiU       none  UCOaZMVOKzeunRuvTvNBvtMA
# 155118   SogcWMwjxS0       none  UCgoxyzvouZM-tCgsYzrYtyg
# 144774   XMCPIXOI_ZA       none  UCmoX4QULJ9MB00xW4coMiOw
# 27676    NFiHLJ-E_xs       none  UChBEbMKI1eCcejTtmI32UEw
# 1091792  zQawJBSx0f0       none  UCwr3OhGtU4HLWSjYOxXliZA
#
#                        chan_name  chan_viewcount  chan_subcount  \
# 235123       Mi Vida en un Dulce        17635008         176000
# 1034336       India Food Network       117758625         462000
# 1089564             Food Insider      1705649569        4460000
# 114769                  Toniawyt          354622           2280
# 1107487       CupofJoe Caribbean          620204           4640
# 116572         Beers-Jack of BBQ         1047240           6400
# 155118            NishaMadhulika      2728583942       13100000
# 144774   Sanjeev Kapoor Khazana       1374735008        7130000
# 27676            Joshua Weissman       936326402        7090000
# 1091792        Sharmin’s Kitchen         2412118          14000
#
#                        chan_start_dt  \
# 235123          2015-12-22T19:48:51Z
# 1034336         2012-08-28T10:02:17Z
# 1089564         2017-10-17T21:11:29Z
# 114769          2018-11-21T20:46:18Z
# 1107487         2014-08-06T00:21:42Z
# 116572          2017-12-07T22:41:52Z
# 155118          2009-08-02T13:13:39Z
# 144774          2009-07-29T04:09:28Z
# 27676           2014-02-28T00:03:34Z
# 1091792  2019-12-08T03:20:48.639258Z
#
#                                                 chan_thumb  chan_vidcount  \
# 235123   https://yt3.ggpht.com/ytc/AMLnZu-D26J_yQ5ScSta...            253
# 1034336  https://yt3.ggpht.com/ytc/AMLnZu8tGj3ow2dHlAzf...           2952
# 1089564  https://yt3.ggpht.com/ytc/AMLnZu80hN5x1GVlHZ3V...           1332
# 114769   https://yt3.ggpht.com/ytc/AMLnZu8EPZGl4TSfiK5Z...            251
# 1107487  https://yt3.ggpht.com/ytc/AMLnZu--7E0r3KAQZMD6...           1532
# 116572   https://yt3.ggpht.com/ytc/AMLnZu8Cu7fqvL04nKsg...            191
# 155118   https://yt3.ggpht.com/821Dq97TRsnhpQhewahvSJPa...           1973
# 144774   https://yt3.ggpht.com/GVTtEiBD6Mt1FR_Y5FKgYa8m...          12787
# 27676    https://yt3.ggpht.com/ytc/AMLnZu-2pyUTWSFy7qzi...            465
# 1091792  https://yt3.ggpht.com/ytc/AMLnZu-Xmm3xJplRvQ-6...            780
#
#                                                   vid_name  ...  \
# 235123                Queque de Camote con Miel y Especias  ...
# 1034336                Baisakhi Special Puri Aloo By Seema  ...
# 1089564                    Mega Poke Bowl Weighs 20 Pounds  ...
# 114769   Lemon Yogurt Cake Recipe || Lemon Bundt Cake R...  ...
# 1107487  SPICED FROZEN HOT CHOCOLATE | Joel | Zan | Ova...  ...
# 116572   Smashburgers on the Kamado Joe Soapstone! Pit ...  ...
# 155118   Rava upma recipe - Sooji Upma Recipe - Semolin...  ...
# 144774   Apple Halwa | एप्पल हलवा | Sanjeev Kapoor Khazana  ...
# 27676    How To Make Steamed Dumplings Completely From ...  ...
# 1091792  How to make Fried Grey Snapper Curry Guyanese ...  ...
#
#         subtitle_words_unique has_profanity has_music  has_links  link_perc  \
# 235123                     11         False     False       True   0.049689
# 1034336                   176         False     False       True   0.282178
# 1089564                   128         False      True       True   0.282670
# 114769                      2         False      True      False   0.000000
# 1107487                   112          True      True       True   0.545673
# 116572                    340         False      True       True   0.212436
# 155118                      5         False     False       True   0.422535
# 144774                      1         False     False       True   0.117647
# 27676                     612         False      True       True   0.377868
# 1091792                   294         False      True      False   0.000000
#
#             pca_0     pca_1     pca_2     pca_3     pca_4
# 235123   0.405978 -0.142340  0.011053 -0.379024  0.248060
# 1034336  0.325901 -0.163726 -0.081613 -0.075811  0.000991
# 1089564 -0.166292  0.314252  0.178171  0.021380 -0.119654
# 114769   0.254448  0.917287  0.396814 -0.132439 -0.144223
# 1107487  0.050354  0.189444 -0.055459  0.051938  0.063780
# 116572  -0.102059 -0.225031  0.201870 -0.025316 -0.006821
# 155118   0.589815  0.058319 -0.312450  0.272837  0.113087
# 144774   0.254448  0.917287  0.396814 -0.132439 -0.144223
# 27676   -0.062335 -0.100895 -0.059750  0.115902 -0.075143
# 1091792  0.123817 -0.159194  0.234670  0.416281  0.180853
#
# [10 rows x 51 columns]
